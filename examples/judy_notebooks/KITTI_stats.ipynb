# %%
import os
import avstack
import avapi
from matplotlib import pyplot as plt
import numpy as np

# %load_ext autoreload
# %autoreload 2

# Importing data
data_base = '../../data'
obj_data_dir_k = os.path.join(data_base, 'KITTI/object')
raw_data_dir_k = os.path.join(data_base, 'KITTI/raw')
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Instantiating Scene Manager
KSM = avapi.kitti.KittiScenesManager(obj_data_dir_k, raw_data_dir_k, convert_raw=False)

# %%
dict = {} # dict for tracking number of objects of each type
frame_idx = 0

# Checking each file in dataset
for i in range(len(KSM.scenes)):
    # Deriving SceneDataset from SceneManager
    KDM = KSM.get_scene_dataset_by_index(scene_idx=i)
    # Get a frame and the objects in that frame
    if KDM.frames is None:
        continue
    frame = KDM.get_frames(sensor="main_camera")[frame_idx]
    objects = KDM.get_objects(frame, sensor='main_lidar')
    # count number of objects of each type (update dict)
    sceneDict = {}
    for obj in objects:
        if dict.get(obj.obj_type):
            dict[obj.obj_type] += 1
        else:
            dict[obj.obj_type] = 1
        
        if sceneDict.get(obj.obj_type):
            sceneDict[obj.obj_type] += 1
        else:
            sceneDict[obj.obj_type] = 1
    print('----Types of objects and # of objects of each type in scene: ', i)
    print(sceneDict)

print('========================================================================================')
print('# of objects of each different type of objects in KITTI Dataset at frame:', frame_idx)
print(dict)
# Out:
# ----Types of objects and # of objects of each type in scene:  0
# {'Car': 4}
# ----Types of objects and # of objects of each type in scene:  1
# {'Car': 4}
# ----Types of objects and # of objects of each type in scene:  2
# {'Cyclist': 2}
# No indices available for ../../data/KITTI/object/2011_09_26_drive_0005_sync!
# ----Types of objects and # of objects of each type in scene:  4
# {'Car': 7}
# ----Types of objects and # of objects of each type in scene:  5
# {'Car': 3}
# ----Types of objects and # of objects of each type in scene:  6
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  7
# {'Car': 4}
# ----Types of objects and # of objects of each type in scene:  8
# {'Car': 3}
# ----Types of objects and # of objects of each type in scene:  9
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  10
# {'Car': 1}
# ----Types of objects and # of objects of each type in scene:  11
# {}
# ----Types of objects and # of objects of each type in scene:  12
# {'Car': 5, 'Cyclist': 2}
# ----Types of objects and # of objects of each type in scene:  13
# {'Car': 1}
# ----Types of objects and # of objects of each type in scene:  14
# {'Car': 7}
# ----Types of objects and # of objects of each type in scene:  15
# {'Car': 1}
# ----Types of objects and # of objects of each type in scene:  16
# {}
# ----Types of objects and # of objects of each type in scene:  17
# {'Car': 1}
# ----Types of objects and # of objects of each type in scene:  18
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  19
# {'Pedestrian': 2, 'Car': 7}
# ----Types of objects and # of objects of each type in scene:  20
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  21
# {'Car': 5}
# ----Types of objects and # of objects of each type in scene:  22
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  23
# {'Car': 4}
# ----Types of objects and # of objects of each type in scene:  24
# {'Car': 2, 'Cyclist': 1}
# ----Types of objects and # of objects of each type in scene:  25
# {'Car': 4}
# ----Types of objects and # of objects of each type in scene:  26
# {'Car': 3}
# ----Types of objects and # of objects of each type in scene:  27
# {'Car': 6}
# ----Types of objects and # of objects of each type in scene:  28
# {'Car': 8, 'Pedestrian': 4}
# ----Types of objects and # of objects of each type in scene:  29
# {'Cyclist': 1, 'Car': 2}
# ----Types of objects and # of objects of each type in scene:  30
# {'Car': 1}
# ----Types of objects and # of objects of each type in scene:  31
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  32
# {}
# ----Types of objects and # of objects of each type in scene:  33
# {'Car': 2}
# ----Types of objects and # of objects of each type in scene:  34
# {'Car': 5}
# ----Types of objects and # of objects of each type in scene:  35
# {'Cyclist': 1, 'Car': 1}
# ----Types of objects and # of objects of each type in scene:  36
# {'Car': 1}
# ========================================================================================
# # of objects of each different type of objects in KITTI Dataset at frame: 0
# {'Car': 104, 'Cyclist': 7, 'Pedestrian': 6}

# %%
# Plot statistics on objects - what does a scene look like when a car drives around? 
# Mean number of objects per frame, mean number of objects 
# Standard deviation 
# Distribution 
# Make plots in notebook

mean_obj_frame = []
for i in range(len(KSM.scenes)):
    # Deriving SceneDataset from SceneManager
    obj_frame_scene = []
    KDM = KSM.get_scene_dataset_by_index(scene_idx=i)
    if KDM.frames is None:
        continue
    for frame_idx in range(len(KDM.frames)):
        frame = KDM.get_frames(sensor="main_camera")[frame_idx]
        objects = KDM.get_objects(frame, sensor='main_lidar')
        obj_frame_scene.append(len(objects))

    mean = np.mean(obj_frame_scene)
    mean_obj_frame.append(mean)
    
    print('----Mean number of objects per frame in scene: ', i)
    print(mean)
    print('----Standard deviation of objects per frame in scene: ', i)
    print(np.std(obj_frame_scene))
    # plot number of objects across frames
    x = list(range(len(obj_frame_scene)))
    y = obj_frame_scene
    print('----Plot of Scene: ', i)
    plt.xlabel('Frame')  
    plt.ylabel('Number of Objects')  
    title = 'Number of Objects vs Frame: Scene ' + str(i)
    plt.title(title) 
    plt.plot(x, y)
    plt.show()

print('----Mean number of objects per scene: ', np.mean(mean_obj_frame)) # not sure if this is the correct way to calculate it (taking mean of mean)

# standard deviation
print('----Standard deviation of objects per scene: ', np.std(mean_obj_frame))

# plot mean number of objects per frame across scenes
x = list(range(len(mean_obj_frame)))
y = mean_obj_frame
plt.xlabel('Scene')  
plt.ylabel('Mean Number of Objects Per Frame')  

# displaying the title 
plt.title("Mean Number of Objects Per Frame vs Scene: KITTI Dataset") 
plt.plot(x, y)
plt.show()
# Out:
# ----Mean number of objects per frame in scene:  0
# 4.166666666666667
# ----Standard deviation of objects per frame in scene:  0
# 1.3505828645714686
# ----Plot of Scene:  0
# ----Mean number of objects per frame in scene:  1
# 4.166666666666667
# ----Standard deviation of objects per frame in scene:  1
# 1.3505828645714686
# ----Plot of Scene:  1
# ----Mean number of objects per frame in scene:  2
# 0.7142857142857143
# ----Standard deviation of objects per frame in scene:  2
# 0.7871886992567138
# ----Plot of Scene:  2
# No indices available for ../../data/KITTI/object/2011_09_26_drive_0005_sync!
# ----Mean number of objects per frame in scene:  4
# 6.374717832957111
# ----Standard deviation of objects per frame in scene:  4
# 3.2668375578203106
# ----Plot of Scene:  4
# ----Mean number of objects per frame in scene:  5
# 5.510729613733906
# ----Standard deviation of objects per frame in scene:  5
# 2.798085777280608
# ----Plot of Scene:  5
# ----Mean number of objects per frame in scene:  6
# 2.5
# ----Standard deviation of objects per frame in scene:  6
# 0.9428090415820634
# ----Plot of Scene:  6
# ----Mean number of objects per frame in scene:  7
# 3.0031847133757963
# ----Standard deviation of objects per frame in scene:  7
# 1.8485635801427045
# ----Plot of Scene:  7
# ----Mean number of objects per frame in scene:  8
# 4.754208754208754
# ----Standard deviation of objects per frame in scene:  8
# 1.872229480899431
# ----Plot of Scene:  8
# ----Mean number of objects per frame in scene:  9
# 0.7368421052631579
# ----Standard deviation of objects per frame in scene:  9
# 0.7953001373082902
# ----Plot of Scene:  9
# ----Mean number of objects per frame in scene:  10
# 2.0037037037037035
# ----Standard deviation of objects per frame in scene:  10
# 1.6788403143531532
# ----Plot of Scene:  10
# ----Mean number of objects per frame in scene:  11
# 2.2557172557172556
# ----Standard deviation of objects per frame in scene:  11
# 2.4288403919947887
# ----Plot of Scene:  11
# ----Mean number of objects per frame in scene:  12
# 4.604651162790698
# ----Standard deviation of objects per frame in scene:  12
# 0.8528893405066161
# ----Plot of Scene:  12
# ----Mean number of objects per frame in scene:  13
# 2.815
# ----Standard deviation of objects per frame in scene:  13
# 2.3357600476076303
# ----Plot of Scene:  13
# ----Mean number of objects per frame in scene:  14
# 8.61603375527426
# ----Standard deviation of objects per frame in scene:  14
# 2.9802861922792103
# ----Plot of Scene:  14
# ----Mean number of objects per frame in scene:  15
# 0.19680851063829788
# ----Standard deviation of objects per frame in scene:  15
# 0.49313416405412047
# ----Plot of Scene:  15
# ----Mean number of objects per frame in scene:  16
# 0.4069767441860465
# ----Standard deviation of objects per frame in scene:  16
# 0.5822551781499439
# ----Plot of Scene:  16
# ----Mean number of objects per frame in scene:  17
# 0.20465116279069767
# ----Standard deviation of objects per frame in scene:  17
# 0.45235995564969295
# ----Plot of Scene:  17
# ----Mean number of objects per frame in scene:  18
# 2.682051282051282
# ----Standard deviation of objects per frame in scene:  18
# 1.13744468332599
# ----Plot of Scene:  18
# ----Mean number of objects per frame in scene:  19
# 7.038167938931298
# ----Standard deviation of objects per frame in scene:  19
# 1.2745577299247843
# ----Plot of Scene:  19
# ----Mean number of objects per frame in scene:  20
# 3.5915317559153177
# ----Standard deviation of objects per frame in scene:  20
# 4.533811321702447
# ----Plot of Scene:  20
# ----Mean number of objects per frame in scene:  21
# 4.00253164556962
# ----Standard deviation of objects per frame in scene:  21
# 1.7538366394448823
# ----Plot of Scene:  21
# ----Mean number of objects per frame in scene:  22
# 1.28
# ----Standard deviation of objects per frame in scene:  22
# 1.2432216214336045
# ----Plot of Scene:  22
# ----Mean number of objects per frame in scene:  23
# 4.954545454545454
# ----Standard deviation of objects per frame in scene:  23
# 0.5622416762205902
# ----Plot of Scene:  23
# ----Mean number of objects per frame in scene:  24
# 2.863013698630137
# ----Standard deviation of objects per frame in scene:  24
# 1.9218645946997133
# ----Plot of Scene:  24
# ----Mean number of objects per frame in scene:  25
# 3.2564102564102564
# ----Standard deviation of objects per frame in scene:  25
# 0.43665093245965136
# ----Plot of Scene:  25
# ----Mean number of objects per frame in scene:  26
# 2.2006802721088436
# ----Standard deviation of objects per frame in scene:  26
# 1.2792959691508607
# ----Plot of Scene:  26
# ----Mean number of objects per frame in scene:  27
# 5.717451523545706
# ----Standard deviation of objects per frame in scene:  27
# 1.6802420807330414
# ----Plot of Scene:  27
# ----Mean number of objects per frame in scene:  28
# 9.726541554959786
# ----Standard deviation of objects per frame in scene:  28
# 4.279168080371398
# ----Plot of Scene:  28
# ----Mean number of objects per frame in scene:  29
# 3.1794871794871793
# ----Standard deviation of objects per frame in scene:  29
# 0.7115095859236722
# ----Plot of Scene:  29
# ----Mean number of objects per frame in scene:  30
# 2.5718349928876245
# ----Standard deviation of objects per frame in scene:  30
# 2.33719456295785
# ----Plot of Scene:  30
# ----Mean number of objects per frame in scene:  31
# 2.9368421052631577
# ----Standard deviation of objects per frame in scene:  31
# 1.5881835126351407
# ----Plot of Scene:  31
# ----Mean number of objects per frame in scene:  32
# 0.28809523809523807
# ----Standard deviation of objects per frame in scene:  32
# 0.5480277977622864
# ----Plot of Scene:  32
# ----Mean number of objects per frame in scene:  33
# 0.71
# ----Standard deviation of objects per frame in scene:  33
# 0.7783957862167551
# ----Plot of Scene:  33
# ----Mean number of objects per frame in scene:  34
# 7.093994778067885
# ----Standard deviation of objects per frame in scene:  34
# 2.1922103894511675
# ----Plot of Scene:  34
# ----Mean number of objects per frame in scene:  35
# 0.4490084985835694
# ----Standard deviation of objects per frame in scene:  35
# 0.6168827625278389
# ----Plot of Scene:  35
# ----Mean number of objects per frame in scene:  36
# 0.4458161865569273
# ----Standard deviation of objects per frame in scene:  36
# 0.5973302967030842
# ----Plot of Scene:  36
# ----Mean number of objects per scene:  3.2783013534407774
# ----Standard deviation of objects per scene:  2.414639059415228
