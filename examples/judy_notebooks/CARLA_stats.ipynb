# %%
import os
import avstack
import avapi
from matplotlib import pyplot as plt
import numpy as np

# %load_ext autoreload
# %autoreload 2

# Importing data
data_base = '../../data'
data_dir_c = os.path.join(data_base, 'CARLA/ego-lidar')
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Instantiating Scene Manager
CSM = avapi.carla.CarlaScenesManager(data_dir_c)

# %%
dict = {} # dict for tracking number of objects of each type
frame_idx = 10
# Checking each file in dataset
for i in range(len(CSM.scenes)):
    # Deriving SceneDataset from SceneManager
    CDM = CSM.get_scene_dataset_by_index(scene_idx=i)
    # Get a frame and the objects in that frame
    frame = CDM.get_frames(sensor="main_camera")[frame_idx]
    objects = CDM.get_objects(frame, sensor='main_lidar')
    # count number of objects of each type (update dict)
    sceneDict = {}
    for obj in objects:
        if dict.get(obj.obj_type):
            dict[obj.obj_type] += 1
        else:
            dict[obj.obj_type] = 1
        
        if sceneDict.get(obj.obj_type):
            sceneDict[obj.obj_type] += 1
        else:
            sceneDict[obj.obj_type] = 1
    print('----Types of objects and # of objects of each type in scene: ', i)
    print(sceneDict)

print('========================================================================================')
print('# of objects of each different type of objects in CARLA Dataset at frame:', frame_idx)
print(dict)
# Out:
# ----Types of objects and # of objects of each type in scene:  0
# {'truck': 5, 'bicycle': 1, 'car': 14}
# ----Types of objects and # of objects of each type in scene:  1
# {'truck': 4, 'car': 11, 'motorcycle': 2, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  2
# {'car': 19, 'bicycle': 6, 'truck': 11, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  3
# {'car': 14, 'truck': 6, 'motorcycle': 1, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  4
# {'car': 25, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  5
# {'truck': 7, 'car': 8, 'motorcycle': 1, 'bicycle': 3}
# ----Types of objects and # of objects of each type in scene:  6
# {'car': 13, 'truck': 4, 'bicycle': 3, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  7
# {'car': 31, 'motorcycle': 3, 'truck': 9, 'bicycle': 3}
# ----Types of objects and # of objects of each type in scene:  8
# {'car': 12, 'motorcycle': 1, 'truck': 4, 'bicycle': 3}
# ----Types of objects and # of objects of each type in scene:  9
# {'motorcycle': 2, 'car': 17, 'truck': 6, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  10
# {'car': 1, 'truck': 5, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  11
# {'truck': 12, 'car': 21, 'bicycle': 3, 'motorcycle': 1}
# ----Types of objects and # of objects of each type in scene:  12
# {'bicycle': 2, 'truck': 5, 'car': 7}
# ----Types of objects and # of objects of each type in scene:  13
# {'car': 18, 'bicycle': 3, 'truck': 8}
# ----Types of objects and # of objects of each type in scene:  14
# {'truck': 5, 'car': 23, 'bicycle': 3, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  15
# {'car': 21, 'truck': 10, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  16
# {'car': 37, 'truck': 8, 'motorcycle': 2, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  17
# {'car': 14, 'truck': 4, 'bicycle': 3}
# ----Types of objects and # of objects of each type in scene:  18
# {'car': 22, 'truck': 6, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  19
# {'car': 19, 'truck': 2, 'bicycle': 1, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  20
# {'car': 13, 'bicycle': 2, 'truck': 3}
# ----Types of objects and # of objects of each type in scene:  21
# {'car': 33, 'truck': 9, 'bicycle': 5, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  22
# {'car': 31, 'truck': 10, 'bicycle': 5}
# ----Types of objects and # of objects of each type in scene:  23
# {'truck': 10, 'car': 10, 'bicycle': 2, 'motorcycle': 1}
# ----Types of objects and # of objects of each type in scene:  24
# {'car': 23, 'truck': 6, 'motorcycle': 1, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  25
# {'car': 9, 'truck': 4, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  26
# {'motorcycle': 1, 'truck': 5, 'car': 9, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  27
# {'car': 28, 'motorcycle': 3, 'truck': 9, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  28
# {'car': 17, 'truck': 3, 'bicycle': 3, 'motorcycle': 1}
# ----Types of objects and # of objects of each type in scene:  29
# {'truck': 12, 'car': 25, 'bicycle': 3, 'motorcycle': 4}
# ----Types of objects and # of objects of each type in scene:  30
# {'truck': 7, 'car': 19, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  31
# {'car': 14, 'bicycle': 3, 'truck': 3, 'motorcycle': 3}
# ----Types of objects and # of objects of each type in scene:  32
# {'motorcycle': 2, 'car': 19, 'truck': 7, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  33
# {'car': 19, 'motorcycle': 2, 'truck': 5, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  34
# {'car': 26, 'truck': 7, 'bicycle': 6}
# ----Types of objects and # of objects of each type in scene:  35
# {'car': 18, 'truck': 7, 'motorcycle': 3, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  36
# {'motorcycle': 1, 'bicycle': 2, 'car': 17, 'truck': 4}
# ----Types of objects and # of objects of each type in scene:  37
# {'truck': 3, 'car': 15, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  38
# {'motorcycle': 2, 'car': 10, 'truck': 2, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  39
# {'truck': 2, 'car': 13, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  40
# {'truck': 4, 'car': 14, 'motorcycle': 1, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  41
# {'bicycle': 5, 'car': 14, 'truck': 1}
# ----Types of objects and # of objects of each type in scene:  42
# {'car': 20, 'motorcycle': 6, 'truck': 6, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  43
# {'car': 17, 'truck': 3, 'bicycle': 1}
# ----Types of objects and # of objects of each type in scene:  44
# {'car': 34, 'truck': 11, 'motorcycle': 2, 'bicycle': 2}
# ----Types of objects and # of objects of each type in scene:  45
# {'truck': 10, 'car': 6, 'motorcycle': 2}
# ----Types of objects and # of objects of each type in scene:  46
# {'truck': 8, 'car': 15, 'bicycle': 6}
# ----Types of objects and # of objects of each type in scene:  47
# {'car': 15, 'truck': 4, 'motorcycle': 1}
# ----Types of objects and # of objects of each type in scene:  48
# {'car': 16, 'truck': 10, 'bicycle': 3}
# ----Types of objects and # of objects of each type in scene:  49
# {'bicycle': 3, 'motorcycle': 3, 'car': 12, 'truck': 4}
# ========================================================================================
# # of objects of each different type of objects in CARLA Dataset at frame: 10
# {'truck': 300, 'bicycle': 112, 'car': 878, 'motorcycle': 68}

# %%
# Plot statistics on objects - what does a scene look like when a car drives around? 
# Mean number of objects per frame, mean number of objects 
# Standard deviation 
# Distribution 
# Make plots in notebook

mean_obj_frame = []
idx_frame_start = 4
idx_frame_end = -4

for i in range(len(CSM.scenes)):
    # Deriving SceneDataset from SceneManager
    obj_frame_scene = []
    CDM = CSM.get_scene_dataset_by_index(scene_idx=i)
    for frame in CDM.get_frames(sensor="main_camera")[idx_frame_start:idx_frame_end]:
        objects = CDM.get_objects(frame, sensor='main_lidar')
        obj_frame_scene.append(len(objects))

    mean = np.mean(obj_frame_scene)
    mean_obj_frame.append(mean)
    
    print('----Mean number of objects per frame in scene: ', i)
    print(mean)
    print('----Standard deviation of objects per frame in scene: ', i)
    print(np.std(obj_frame_scene))
    # plot number of objects across frames
    x = list(range(len(obj_frame_scene)))
    y = obj_frame_scene
    print('----Plot of Scene: ', i)
    plt.xlabel('Frame')  
    plt.ylabel('Number of Objects')  
    title = 'Number of Objects vs Frame: Scene ' + str(i)
    plt.title(title) 
    plt.plot(x, y)
    plt.show()

print('----Mean number of objects per scene: ', np.mean(mean_obj_frame)) # not sure if this is the correct way to calculate it (taking mean of mean)

# standard deviation
print('----Standard deviation of objects per scene: ', np.std(mean_obj_frame))

# plot mean number of objects per frame across scenes
x = list(range(len(mean_obj_frame)))
y = mean_obj_frame
plt.xlabel('Scene')  
plt.ylabel('Mean Number of Objects Per Frame')  

# displaying the title 
plt.title("Mean Number of Objects Per Frame vs Scene: CARLA Dataset") 
plt.plot(x, y)
plt.show()
# Out:
# ----Mean number of objects per frame in scene:  0
# 23.793367346938776
# ----Standard deviation of objects per frame in scene:  0
# 6.4039733271821415
# ----Plot of Scene:  0
# ----Mean number of objects per frame in scene:  1
# 21.59846547314578
# ----Standard deviation of objects per frame in scene:  1
# 2.7865034049485735
# ----Plot of Scene:  1
# ----Mean number of objects per frame in scene:  2
# 32.20460358056266
# ----Standard deviation of objects per frame in scene:  2
# 2.6796723248716128
# ----Plot of Scene:  2
# ----Mean number of objects per frame in scene:  3
# 25.915601023017903
# ----Standard deviation of objects per frame in scene:  3
# 3.077936845844408
# ----Plot of Scene:  3
# ----Mean number of objects per frame in scene:  4
# 20.514066496163682
# ----Standard deviation of objects per frame in scene:  4
# 3.473565734397333
# ----Plot of Scene:  4
# ----Mean number of objects per frame in scene:  5
# 27.595907928388748
# ----Standard deviation of objects per frame in scene:  5
# 4.892750901889678
# ----Plot of Scene:  5
# ----Mean number of objects per frame in scene:  6
# 25.544757033248082
# ----Standard deviation of objects per frame in scene:  6
# 3.0347378200792456
# ----Plot of Scene:  6
# ----Mean number of objects per frame in scene:  7
# 21.398976982097185
# ----Standard deviation of objects per frame in scene:  7
# 8.243692402472337
# ----Plot of Scene:  7
# ----Mean number of objects per frame in scene:  8
# 19.053708439897697
# ----Standard deviation of objects per frame in scene:  8
# 7.117909425180222
# ----Plot of Scene:  8
# ----Mean number of objects per frame in scene:  9
# 35.1381074168798
# ----Standard deviation of objects per frame in scene:  9
# 6.103234268884923
# ----Plot of Scene:  9
# ----Mean number of objects per frame in scene:  10
# 14.838874680306905
# ----Standard deviation of objects per frame in scene:  10
# 4.7313637925270715
# ----Plot of Scene:  10
# ----Mean number of objects per frame in scene:  11
# 35.72378516624041
# ----Standard deviation of objects per frame in scene:  11
# 3.2422123094777135
# ----Plot of Scene:  11
# ----Mean number of objects per frame in scene:  12
# 13.51150895140665
# ----Standard deviation of objects per frame in scene:  12
# 4.637139686809511
# ----Plot of Scene:  12
# ----Mean number of objects per frame in scene:  13
# 23.388746803069054
# ----Standard deviation of objects per frame in scene:  13
# 4.883007355471577
# ----Plot of Scene:  13
# ----Mean number of objects per frame in scene:  14
# 22.14833759590793
# ----Standard deviation of objects per frame in scene:  14
# 6.110532691049279
# ----Plot of Scene:  14
# ----Mean number of objects per frame in scene:  15
# 30.375959079283888
# ----Standard deviation of objects per frame in scene:  15
# 5.3653558612180685
# ----Plot of Scene:  15
# ----Mean number of objects per frame in scene:  16
# 28.56777493606138
# ----Standard deviation of objects per frame in scene:  16
# 9.123751915373678
# ----Plot of Scene:  16
# ----Mean number of objects per frame in scene:  17
# 20.199488491048594
# ----Standard deviation of objects per frame in scene:  17
# 5.8712616440885865
# ----Plot of Scene:  17
# ----Mean number of objects per frame in scene:  18
# 30.966751918158568
# ----Standard deviation of objects per frame in scene:  18
# 5.190136172672647
# ----Plot of Scene:  18
# ----Mean number of objects per frame in scene:  19
# 27.391304347826086
# ----Standard deviation of objects per frame in scene:  19
# 3.4191915239122492
# ----Plot of Scene:  19
# ----Mean number of objects per frame in scene:  20
# 19.398976982097185
# ----Standard deviation of objects per frame in scene:  20
# 3.2475682780655744
# ----Plot of Scene:  20
# ----Mean number of objects per frame in scene:  21
# 23.25063938618926
# ----Standard deviation of objects per frame in scene:  21
# 12.281172805295846
# ----Plot of Scene:  21
# ----Mean number of objects per frame in scene:  22
# 25.04859335038363
# ----Standard deviation of objects per frame in scene:  22
# 7.179837627259943
# ----Plot of Scene:  22
# ----Mean number of objects per frame in scene:  23
# 22.37851662404092
# ----Standard deviation of objects per frame in scene:  23
# 2.348193809693359
# ----Plot of Scene:  23
# ----Mean number of objects per frame in scene:  24
# 26.918158567774935
# ----Standard deviation of objects per frame in scene:  24
# 5.356684538350048
# ----Plot of Scene:  24
# ----Mean number of objects per frame in scene:  25
# 22.296675191815858
# ----Standard deviation of objects per frame in scene:  25
# 2.6402286567592568
# ----Plot of Scene:  25
# ----Mean number of objects per frame in scene:  26
# 23.805626598465473
# ----Standard deviation of objects per frame in scene:  26
# 4.303459508094522
# ----Plot of Scene:  26
# ----Mean number of objects per frame in scene:  27
# 26.718670076726344
# ----Standard deviation of objects per frame in scene:  27
# 5.7454649542719345
# ----Plot of Scene:  27
# ----Mean number of objects per frame in scene:  28
# 23.005115089514067
# ----Standard deviation of objects per frame in scene:  28
# 4.965350470375658
# ----Plot of Scene:  28
# ----Mean number of objects per frame in scene:  29
# 23.987212276214834
# ----Standard deviation of objects per frame in scene:  29
# 8.444029059367947
# ----Plot of Scene:  29
# ----Mean number of objects per frame in scene:  30
# 29.808184143222505
# ----Standard deviation of objects per frame in scene:  30
# 5.505777902240725
# ----Plot of Scene:  30
# ----Mean number of objects per frame in scene:  31
# 23.324808184143222
# ----Standard deviation of objects per frame in scene:  31
# 5.301582391922938
# ----Plot of Scene:  31
# ----Mean number of objects per frame in scene:  32
# 26.91304347826087
# ----Standard deviation of objects per frame in scene:  32
# 5.106798907835138
# ----Plot of Scene:  32
# ----Mean number of objects per frame in scene:  33
# 22.55754475703325
# ----Standard deviation of objects per frame in scene:  33
# 2.8912316701100673
# ----Plot of Scene:  33
# ----Mean number of objects per frame in scene:  34
# 36.28388746803069
# ----Standard deviation of objects per frame in scene:  34
# 4.5192083623828045
# ----Plot of Scene:  34
# ----Mean number of objects per frame in scene:  35
# 30.923273657289002
# ----Standard deviation of objects per frame in scene:  35
# 5.029249029915608
# ----Plot of Scene:  35
# ----Mean number of objects per frame in scene:  36
# 26.483375959079282
# ----Standard deviation of objects per frame in scene:  36
# 5.565155097815949
# ----Plot of Scene:  36
# ----Mean number of objects per frame in scene:  37
# 24.994884910485933
# ----Standard deviation of objects per frame in scene:  37
# 5.312724138752001
# ----Plot of Scene:  37
# ----Mean number of objects per frame in scene:  38
# 15.322250639386189
# ----Standard deviation of objects per frame in scene:  38
# 5.401381943903969
# ----Plot of Scene:  38
# ----Mean number of objects per frame in scene:  39
# 25.207161125319693
# ----Standard deviation of objects per frame in scene:  39
# 6.766893220596074
# ----Plot of Scene:  39
# ----Mean number of objects per frame in scene:  40
# 31.434782608695652
# ----Standard deviation of objects per frame in scene:  40
# 3.4128113365267754
# ----Plot of Scene:  40
# ----Mean number of objects per frame in scene:  41
# 19.585677749360613
# ----Standard deviation of objects per frame in scene:  41
# 6.241286467205279
# ----Plot of Scene:  41
# ----Mean number of objects per frame in scene:  42
# 24.910485933503836
# ----Standard deviation of objects per frame in scene:  42
# 6.376881800927398
# ----Plot of Scene:  42
# ----Mean number of objects per frame in scene:  43
# 29.37851662404092
# ----Standard deviation of objects per frame in scene:  43
# 6.967953597666801
# ----Plot of Scene:  43
# ----Mean number of objects per frame in scene:  44
# 30.171355498721226
# ----Standard deviation of objects per frame in scene:  44
# 8.087994193913705
# ----Plot of Scene:  44
# ----Mean number of objects per frame in scene:  45
# 20.66751918158568
# ----Standard deviation of objects per frame in scene:  45
# 2.546135677653148
# ----Plot of Scene:  45
# ----Mean number of objects per frame in scene:  46
# 20.90537084398977
# ----Standard deviation of objects per frame in scene:  46
# 4.341407930204086
# ----Plot of Scene:  46
# ----Mean number of objects per frame in scene:  47
# 22.575447570332482
# ----Standard deviation of objects per frame in scene:  47
# 4.5260045151647885
# ----Plot of Scene:  47
# ----Mean number of objects per frame in scene:  48
# 21.82608695652174
# ----Standard deviation of objects per frame in scene:  48
# 3.486244035608311
# ----Plot of Scene:  48
# ----Mean number of objects per frame in scene:  49
# 24.273657289002557
# ----Standard deviation of objects per frame in scene:  49
# 3.157307389065141
# ----Plot of Scene:  49
# ----Mean number of objects per scene:  24.88451184821755
# ----Standard deviation of objects per scene:  4.968963324937638
